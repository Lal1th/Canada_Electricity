# %%
import pandas as pd

# %%
ab=pd.read_excel("/content/End_Use_Demand_AB.xlsx")
bc=pd.read_excel("/content/End_Use_Demand_BC.xlsx")
can=pd.read_excel("/content/End_Use_Demand_Can.xlsx")
mb=pd.read_excel("/content/End_Use_Demand_MB.xlsx")
on=pd.read_excel("/content/End_Use_Demand_ON.xlsx")
qc=pd.read_excel("/content/End_Use_Demand_QB.xlsx")
sk=pd.read_excel("/content/End_Use_Demand_SK.xlsx")

# %%
ab=ab.T
bc=bc.T
can=can.T
mb=mb.T
on=on.T
qc=qc.T
sk=sk.T

# %%
ab.columns=ab.iloc[0]
bc.columns=bc.iloc[0]
can.columns=can.iloc[0]
mb.columns=mb.iloc[0]
on.columns=on.iloc[0]
qc.columns=qc.iloc[0]
sk.columns=sk.iloc[0]

# %%
ab=ab.iloc[:,6:]
bc=bc.iloc[:,6:]
can=can.iloc[:,6:]
mb=mb.iloc[:,6:]
on=on.iloc[:,6:]
qc=qc.iloc[:,6:]
sk=sk.iloc[:,6:]

# %%
ab = ab.reset_index(drop=True)
ab.columns=ab.iloc[0]
ab.rename_axis('Alberta', inplace=True)

bc =bc.reset_index(drop=True)
bc.columns=bc.iloc[0]
bc.rename_axis('British Columbia', inplace=True)

can = can.reset_index(drop=True)
can.columns=can.iloc[0]
can.rename_axis('Canada', inplace=True)

mb = mb.reset_index(drop=True)
mb.columns=mb.iloc[0]
mb.rename_axis('Manitoba', inplace=True)

on = on.reset_index(drop=True)
on.columns=on.iloc[0]
on.rename_axis('Ontario', inplace=True)

qc = qc.reset_index(drop=True)
qc.columns=qc.iloc[0]
qc.rename_axis('Quebec', inplace=True)

sk = sk.reset_index(drop=True)
sk.columns=sk.iloc[0]
sk.rename_axis('Saskatchewan', inplace=True)

# %%
ab.rename(columns={'_':'Date'}, inplace=True)
bc.rename(columns={'_':'Date'}, inplace=True)
can.rename(columns={'_':'Date'}, inplace=True)
mb.rename(columns={'_':'Date'}, inplace=True)
on.rename(columns={'_':'Date'}, inplace=True)
qc.rename(columns={'_':'Date'}, inplace=True)
sk.rename(columns={'_':'Date'}, inplace=True)

# %%
ab = ab.dropna(axis=1)
bc = bc.dropna(axis=1)
can = can.dropna(axis=1)
mb = mb.dropna(axis=1)
on = on.dropna(axis=1)
qc = qc.dropna(axis=1)
sk = sk.dropna(axis=1)

# %%
ab = ab.drop(index=0)
bc = bc.drop(index=0)
can = can.drop(index=0)
mb = mb.drop(index=0)
on = on.drop(index=0)
qc = qc.drop(index=0)
sk = sk.drop(index=0)

# %%
ab
# Out:
# 0          Date Total End-Use Electricity Natural Gas      RPP  \
# Alberta
# 1        2005.0       2798.72      211.84      1338.7  1125.47
# 2        2006.0       2954.28      222.61     1446.42  1194.21
# 3        2007.0       3127.68      222.51     1591.84  1225.59
# 4        2008.0       3059.32      224.84     1582.86  1170.22
# 5        2009.0        3070.0      225.57     1578.86  1179.97
# 6        2010.0       3198.89      226.28      1651.4   1234.8
# 7        2011.0       3324.77      235.39     1744.85  1244.72
# 8        2012.0       3569.17      243.92     1878.47  1344.01
# 9        2013.0       3650.27      246.92     1971.29  1317.67
# 10       2014.0       3707.94      260.14     2028.67  1305.22
# 11       2015.0       3760.17      267.66     2100.16  1291.33
# 12       2016.0       3657.68      264.53     2044.47  1261.12
# 13       2017.0       3851.42      270.28     2206.71  1284.73
# 14       2018.0        4067.7      273.83      2357.8  1324.26
# ...

# %%
ab['Date'] = ab['Date'].astype(int)
bc['Date'] = bc['Date'].astype(int)
can['Date'] = can['Date'].astype(int)
mb['Date'] = mb['Date'].astype(int)
on['Date'] = on['Date'].astype(int)
qc['Date'] = qc['Date'].astype(int)
sk['Date'] = sk['Date'].astype(int)

# %%
ab_new_column_names = [
    'ab:Date', 'ab:Total_End_Use', 'ab:Electricity_Total', 'ab:Natural_Gas_Total', 'ab:RPP_Total',
    'ab:Biofuels_Emerging_Energy_Total', 'ab:Hydrogen_Total', 'ab:Other_Total',
    'ab:Date_Residential', 'ab:Total_End_Use_Residential', 'ab:Electricity_Residential', 'ab:Natural_Gas_Residential', 'ab:RPP_Residential',
    'ab:Biofuels_Emerging_Energy_Residential', 'ab:Hydrogen_Residential', 'ab:Other_Residential',
    'ab:Date_Commercial', 'ab:Total_End_Use_Commercial', 'ab:Electricity_Commercial', 'ab:Natural_Gas_Commercial', 'ab:RPP_Commercial',
    'ab:Biofuels_Emerging_Energy_Commercial', 'ab:Hydrogen_Commercial', 'ab:Other_Commercial',
    'ab:Date_Industrial', 'ab:Total_End_Use_Industrial', 'ab:Electricity_Industrial', 'ab:Natural_Gas_Industrial', 'ab:RPP_Industrial',
    'ab:Biofuels_Emerging_Energy_Industrial', 'ab:Hydrogen_Industrial', 'ab:Other_Industrial',
    'ab:Date_Transportation', 'ab:Total_End_Use_Transportation', 'ab:Electricity_Transportation', 'ab:LPG_Transportation', 'ab:Natural_Gas_Transportation',
    'ab:Biofuels_Transportation', 'ab:Hydrogen_Transportation', 'ab:Aviation_Fuel_Transportation', 'ab:Diesel_Transportation',
    'ab:Heavy_Fuel_Oil_Transportation', 'ab:Lubricants_Transportation', 'ab:Motor_Gasoline_Transportation'
]

ab.columns = ab_new_column_names

bc_new_column_names = [
    'bc:Date', 'bc:Total_End_Use', 'bc:Electricity_Total', 'bc:Natural_Gas_Total', 'bc:RPP_Total',
    'bc:Biofuels_Emerging_Energy_Total', 'bc:Hydrogen_Total', 'bc:Other_Total',
    'bc:Date_Residential', 'bc:Total_End_Use_Residential', 'bc:Electricity_Residential', 'bc:Natural_Gas_Residential', 'bc:RPP_Residential',
    'bc:Biofuels_Emerging_Energy_Residential', 'bc:Hydrogen_Residential', 'bc:Other_Residential',
    'bc:Date_Commercial', 'bc:Total_End_Use_Commercial', 'bc:Electricity_Commercial', 'bc:Natural_Gas_Commercial', 'bc:RPP_Commercial',
    'bc:Biofuels_Emerging_Energy_Commercial', 'bc:Hydrogen_Commercial', 'bc:Other_Commercial',
    'bc:Date_Industrial', 'bc:Total_End_Use_Industrial', 'bc:Electricity_Industrial', 'bc:Natural_Gas_Industrial', 'bc:RPP_Industrial',
    'bc:Biofuels_Emerging_Energy_Industrial', 'bc:Hydrogen_Industrial', 'bc:Other_Industrial',
    'bc:Date_Transportation', 'bc:Total_End_Use_Transportation', 'bc:Electricity_Transportation', 'bc:LPG_Transportation', 'bc:Natural_Gas_Transportation',
    'bc:Biofuels_Transportation', 'bc:Hydrogen_Transportation', 'bc:Aviation_Fuel_Transportation', 'bc:Diesel_Transportation',
    'bc:Heavy_Fuel_Oil_Transportation', 'bc:Lubricants_Transportation', 'bc:Motor_Gasoline_Transportation'
]

bc.columns = bc_new_column_names

can_new_column_names = [
    'can:Date', 'can:Total_End_Use', 'can:Electricity_Total', 'can:Natural_Gas_Total', 'can:RPP_Total',
    'can:Biofuels_Emerging_Energy_Total', 'can:Hydrogen_Total', 'can:Other_Total',
    'can:Date_Residential', 'can:Total_End_Use_Residential', 'can:Electricity_Residential', 'can:Natural_Gas_Residential', 'can:RPP_Residential',
    'can:Biofuels_Emerging_Energy_Residential', 'can:Hydrogen_Residential', 'can:Other_Residential',
    'can:Date_Commercial', 'can:Total_End_Use_Commercial', 'can:Electricity_Commercial', 'can:Natural_Gas_Commercial', 'can:RPP_Commercial',
    'can:Biofuels_Emerging_Energy_Commercial', 'can:Hydrogen_Commercial', 'can:Other_Commercial',
    'can:Date_Industrial', 'can:Total_End_Use_Industrial', 'can:Electricity_Industrial', 'can:Natural_Gas_Industrial', 'can:RPP_Industrial',
    'can:Biofuels_Emerging_Energy_Industrial', 'can:Hydrogen_Industrial', 'can:Other_Industrial',
    'can:Date_Transportation', 'can:Total_End_Use_Transportation', 'can:Electricity_Transportation', 'can:LPG_Transportation', 'can:Natural_Gas_Transportation',
    'can:Biofuels_Transportation', 'can:Hydrogen_Transportation', 'can:Aviation_Fuel_Transportation', 'can:Diesel_Transportation',
    'can:Heavy_Fuel_Oil_Transportation', 'can:Lubricants_Transportation', 'can:Motor_Gasoline_Transportation'
]
can.columns = can_new_column_names

mb_new_column_names = [
    'mb:Date', 'mb:Total_End_Use', 'mb:Electricity_Total', 'mb:Natural_Gas_Total', 'mb:RPP_Total',
    'mb:Biofuels_Emerging_Energy_Total', 'mb:Hydrogen_Total', 'mb:Other_Total',
    'mb:Date_Residential', 'mb:Total_End_Use_Residential', 'mb:Electricity_Residential', 'mb:Natural_Gas_Residential', 'mb:RPP_Residential',
    'mb:Biofuels_Emerging_Energy_Residential', 'mb:Hydrogen_Residential', 'mb:Other_Residential',
    'mb:Date_Commercial', 'mb:Total_End_Use_Commercial', 'mb:Electricity_Commercial', 'mb:Natural_Gas_Commercial', 'mb:RPP_Commercial',
    'mb:Biofuels_Emerging_Energy_Commercial', 'mb:Hydrogen_Commercial', 'mb:Other_Commercial',
    'mb:Date_Industrial', 'mb:Total_End_Use_Industrial', 'mb:Electricity_Industrial', 'mb:Natural_Gas_Industrial', 'mb:RPP_Industrial',
    'mb:Biofuels_Emerging_Energy_Industrial', 'mb:Hydrogen_Industrial', 'mb:Other_Industrial',
    'mb:Date_Transportation', 'mb:Total_End_Use_Transportation', 'mb:Electricity_Transportation', 'mb:LPG_Transportation', 'mb:Natural_Gas_Transportation',
    'mb:Biofuels_Transportation', 'mb:Hydrogen_Transportation', 'mb:Aviation_Fuel_Transportation', 'mb:Diesel_Transportation',
    'mb:Heavy_Fuel_Oil_Transportation', 'mb:Lubricants_Transportation', 'mb:Motor_Gasoline_Transportation'
]


mb.columns = mb_new_column_names

on_new_column_names = [
    'on:Date', 'on:Total_End_Use', 'on:Electricity_Total', 'on:Natural_Gas_Total', 'on:RPP_Total',
    'on:Biofuels_Emerging_Energy_Total', 'on:Hydrogen_Total', 'on:Other_Total',
    'on:Date_Residential', 'on:Total_End_Use_Residential', 'on:Electricity_Residential', 'on:Natural_Gas_Residential', 'on:RPP_Residential',
    'on:Biofuels_Emerging_Energy_Residential', 'on:Hydrogen_Residential', 'on:Other_Residential',
    'on:Date_Commercial', 'on:Total_End_Use_Commercial', 'on:Electricity_Commercial', 'on:Natural_Gas_Commercial', 'on:RPP_Commercial',
    'on:Biofuels_Emerging_Energy_Commercial', 'on:Hydrogen_Commercial', 'on:Other_Commercial',
    'on:Date_Industrial', 'on:Total_End_Use_Industrial', 'on:Electricity_Industrial', 'on:Natural_Gas_Industrial', 'on:RPP_Industrial',
    'on:Biofuels_Emerging_Energy_Industrial', 'on:Hydrogen_Industrial', 'on:Other_Industrial',
    'on:Date_Transportation', 'on:Total_End_Use_Transportation', 'on:Electricity_Transportation', 'on:LPG_Transportation', 'on:Natural_Gas_Transportation',
    'on:Biofuels_Transportation', 'on:Hydrogen_Transportation', 'on:Aviation_Fuel_Transportation', 'on:Diesel_Transportation',
    'on:Heavy_Fuel_Oil_Transportation', 'on:Lubricants_Transportation', 'on:Motor_Gasoline_Transportation'
]


on.columns = on_new_column_names

qc_new_column_names = [
    'qc:Date', 'qc:Total_End_Use', 'qc:Electricity_Total', 'qc:Natural_Gas_Total', 'qc:RPP_Total',
    'qc:Biofuels_Emerging_Energy_Total', 'qc:Hydrogen_Total', 'qc:Other_Total',
    'qc:Date_Residential', 'qc:Total_End_Use_Residential', 'qc:Electricity_Residential', 'qc:Natural_Gas_Residential', 'qc:RPP_Residential',
    'qc:Biofuels_Emerging_Energy_Residential', 'qc:Hydrogen_Residential', 'qc:Other_Residential',
    'qc:Date_Commercial', 'qc:Total_End_Use_Commercial', 'qc:Electricity_Commercial', 'qc:Natural_Gas_Commercial', 'qc:RPP_Commercial',
    'qc:Biofuels_Emerging_Energy_Commercial', 'qc:Hydrogen_Commercial', 'qc:Other_Commercial',
    'qc:Date_Industrial', 'qc:Total_End_Use_Industrial', 'qc:Electricity_Industrial', 'qc:Natural_Gas_Industrial', 'qc:RPP_Industrial',
    'qc:Biofuels_Emerging_Energy_Industrial', 'qc:Hydrogen_Industrial', 'qc:Other_Industrial',
    'qc:Date_Transportation', 'qc:Total_End_Use_Transportation', 'qc:Electricity_Transportation', 'qc:LPG_Transportation', 'qc:Natural_Gas_Transportation',
    'qc:Biofuels_Transportation', 'qc:Hydrogen_Transportation', 'qc:Aviation_Fuel_Transportation', 'qc:Diesel_Transportation',
    'qc:Heavy_Fuel_Oil_Transportation', 'qc:Lubricants_Transportation', 'qc:Motor_Gasoline_Transportation'
]


qc.columns = qc_new_column_names

sk_new_column_names = [
    'sk:Date', 'sk:Total_End_Use', 'sk:Electricity_Total', 'sk:Natural_Gas_Total', 'sk:RPP_Total',
    'sk:Biofuels_Emerging_Energy_Total', 'sk:Hydrogen_Total', 'sk:Other_Total',
    'sk:Date_Residential', 'sk:Total_End_Use_Residential', 'sk:Electricity_Residential', 'sk:Natural_Gas_Residential', 'sk:RPP_Residential',
    'sk:Biofuels_Emerging_Energy_Residential', 'sk:Hydrogen_Residential', 'sk:Other_Residential',
    'sk:Date_Commercial', 'sk:Total_End_Use_Commercial', 'sk:Electricity_Commercial', 'sk:Natural_Gas_Commercial', 'sk:RPP_Commercial',
    'sk:Biofuels_Emerging_Energy_Commercial', 'sk:Hydrogen_Commercial', 'sk:Other_Commercial',
    'sk:Date_Industrial', 'sk:Total_End_Use_Industrial', 'sk:Electricity_Industrial', 'sk:Natural_Gas_Industrial', 'sk:RPP_Industrial',
    'sk:Biofuels_Emerging_Energy_Industrial', 'sk:Hydrogen_Industrial', 'sk:Other_Industrial',
    'sk:Date_Transportation', 'sk:Total_End_Use_Transportation', 'sk:Electricity_Transportation', 'sk:LPG_Transportation', 'sk:Natural_Gas_Transportation',
    'sk:Biofuels_Transportation', 'sk:Hydrogen_Transportation', 'sk:Aviation_Fuel_Transportation', 'sk:Diesel_Transportation',
    'sk:Heavy_Fuel_Oil_Transportation', 'sk:Lubricants_Transportation', 'sk:Motor_Gasoline_Transportation'
]


sk.columns = sk_new_column_names

# %%
for col in ab_new_column_names:
    ab[col] = pd.to_numeric(ab[col], errors='coerce')
    ab[col] = ab[col].fillna(0)

for col in bc_new_column_names:
    bc[col] = pd.to_numeric(bc[col], errors='coerce')
    bc[col] = bc[col].fillna(0)

for col in can_new_column_names:
    can[col] = pd.to_numeric(can[col], errors='coerce')
    can[col] = can[col].fillna(0)

for col in mb_new_column_names:
    mb[col] = pd.to_numeric(mb[col], errors='coerce')
    mb[col] = mb[col].fillna(0)

for col in on_new_column_names:
    on[col] = pd.to_numeric(on[col], errors='coerce')
    on[col] = on[col].fillna(0)

for col in qc_new_column_names:
    qc[col] = pd.to_numeric(qc[col], errors='coerce')
    qc[col] = qc[col].fillna(0)

for col in sk_new_column_names:
    sk[col] = pd.to_numeric(sk[col], errors='coerce')
    sk[col] = sk[col].fillna(0)
